# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('AB_NYC_2019.csv')

# %%
len(df)
# Out:
# 48895

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
df.shape
# Out:
# (48895, 16)

# %%
selected_columns = ['latitude', 'longitude','minimum_nights', 'number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365', 'room_type', 'neighbourhood_group','price' ]

# %%
data = df[selected_columns]

# %% [markdown]
# price bizim aranan sutunumuz

# %%
data
# Out:
#        latitude  longitude  minimum_nights  number_of_reviews  \
# 0      40.64749  -73.97237               1                  9
# 1      40.75362  -73.98377               1                 45
# 2      40.80902  -73.94190               3                  0
# 3      40.68514  -73.95976               1                270
# 4      40.79851  -73.94399              10                  9
# ...         ...        ...             ...                ...
# 48890  40.67853  -73.94995               2                  0
# 48891  40.70184  -73.93317               4                  0
# 48892  40.81475  -73.94867              10                  0
# 48893  40.75751  -73.99112               1                  0
# 48894  40.76404  -73.98933               7                  0
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.21                               6               365
# 1                   0.38                               2               355
# 2                    NaN                               1               365
# 3                   4.64                               1               194
# 4                   0.10                               1                 0
# ...                  ...                             ...               ...
# 48890                NaN                               2                 9
# 48891                NaN                               2                36
# 48892                NaN                               1                27
# 48893                NaN                               6                 2
# 48894                NaN                               1                23
#
#              room_type neighbourhood_group  price
# 0         Private room            Brooklyn    149
# 1      Entire home/apt           Manhattan    225
# 2         Private room           Manhattan    150
# 3      Entire home/apt            Brooklyn     89
# 4      Entire home/apt           Manhattan     80
# ...                ...                 ...    ...
# 48890     Private room            Brooklyn     70
# 48891     Private room            Brooklyn     40
# 48892  Entire home/apt           Manhattan    115
# 48893      Shared room           Manhattan     55
# 48894     Private room           Manhattan     90
#
# [48895 rows x 10 columns]

# %%
data.describe(include=["O"])
# Out:
#               room_type neighbourhood_group
# count             48895               48895
# unique                3                   5
# top     Entire home/apt           Manhattan
# freq              25409               21661

# %%
from sklearn.model_selection import train_test_split

# %%
df_train_full, df_test = train_test_split(data, test_size=0.2, random_state=42)

# %%
df_train, df_val = train_test_split(df_train_full, test_size=0.33, random_state=42)

# %%
df_train
# Out:
#        latitude  longitude  minimum_nights  number_of_reviews  \
# 28057  40.74496  -73.89534               1                118
# 9104   40.78289  -73.98477              30                 17
# 48811  40.76807  -73.93799               2                  0
# 38140  40.71318  -73.95876               2                 20
# 14623  40.74493  -73.95370               1                  1
# ...         ...        ...             ...                ...
# 13198  40.71748  -73.95685               6                  5
# 14583  40.66397  -73.98538               1                  7
# 6168   40.79994  -73.97001               1                  1
# 12248  40.69585  -73.96344              60                  0
# 20523  40.64438  -73.95484               7                 15
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 28057               6.00                               1               320
# 9104                0.38                              34               202
# 48811                NaN                               2               168
# 38140               2.80                               1               263
# 14623               0.03                               1                 0
# ...                  ...                             ...               ...
# 13198               0.13                               1                 0
# 14583               0.17                               2                 0
# 6168                0.64                               1                88
# 12248                NaN                               1                 0
# 20523               0.49                               2               281
#
#              room_type neighbourhood_group  price
# 28057  Entire home/apt              Queens     99
# 9104   Entire home/apt           Manhattan    125
# 48811     Private room              Queens     95
# 38140  Entire home/apt            Brooklyn    149
# 14623  Entire home/apt              Queens    158
# ...                ...                 ...    ...
# 13198     Private room            Brooklyn     50
# 14583     Private room            Brooklyn    125
# 6168      Private room           Manhattan    299
# 12248     Private room            Brooklyn     65
# 20523  Entire home/apt            Brooklyn     92
#
# [26207 rows x 10 columns]

# %%
df_train
# Out:
#        latitude  longitude  minimum_nights  number_of_reviews  \
# 28057  40.74496  -73.89534               1                118
# 9104   40.78289  -73.98477              30                 17
# 48811  40.76807  -73.93799               2                  0
# 38140  40.71318  -73.95876               2                 20
# 14623  40.74493  -73.95370               1                  1
# ...         ...        ...             ...                ...
# 13198  40.71748  -73.95685               6                  5
# 14583  40.66397  -73.98538               1                  7
# 6168   40.79994  -73.97001               1                  1
# 12248  40.69585  -73.96344              60                  0
# 20523  40.64438  -73.95484               7                 15
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 28057               6.00                               1               320
# 9104                0.38                              34               202
# 48811                NaN                               2               168
# 38140               2.80                               1               263
# 14623               0.03                               1                 0
# ...                  ...                             ...               ...
# 13198               0.13                               1                 0
# 14583               0.17                               2                 0
# 6168                0.64                               1                88
# 12248                NaN                               1                 0
# 20523               0.49                               2               281
#
#              room_type neighbourhood_group  price
# 28057  Entire home/apt              Queens     99
# 9104   Entire home/apt           Manhattan    125
# 48811     Private room              Queens     95
# 38140  Entire home/apt            Brooklyn    149
# 14623  Entire home/apt              Queens    158
# ...                ...                 ...    ...
# 13198     Private room            Brooklyn     50
# 14583     Private room            Brooklyn    125
# 6168      Private room           Manhattan    299
# 12248     Private room            Brooklyn     65
# 20523  Entire home/apt            Brooklyn     92
#
# [26207 rows x 10 columns]

# %%
y_train = df_train.price
y_val = df_val.price
y_test = df_test.price

del df_train['price']
del df_val['price']
del df_test['price']

# %%
data.columns[data.dtypes == float]
# Out:
# Index(['latitude', 'longitude', 'reviews_per_month'], dtype='object')

# %%
data_numeric = data.copy()
data_numeric = data.drop(["neighbourhood_group","room_type", "price"], axis=1)
data_numeric.describe()
# Out:
#            latitude     longitude  minimum_nights  number_of_reviews  \
# count  48895.000000  48895.000000    48895.000000       48895.000000
# mean      40.728949    -73.952170        7.029962          23.274466
# std        0.054530      0.046157       20.510550          44.550582
# min       40.499790    -74.244420        1.000000           0.000000
# 25%       40.690100    -73.983070        1.000000           1.000000
# 50%       40.723070    -73.955680        3.000000           5.000000
# 75%       40.763115    -73.936275        5.000000          24.000000
# max       40.913060    -73.712990     1250.000000         629.000000
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# count       38843.000000                    48895.000000      48895.000000
# mean            1.373221                        7.143982        112.781327
# std             1.680442                       32.952519        131.622289
# min             0.010000                        1.000000          0.000000
# 25%             0.190000                        1.000000          0.000000
# 50%             0.720000                        1.000000         45.000000
# 75%             2.020000                        2.000000        227.000000
# max            58.500000                      327.000000        365.000000

# %%
data_numeric.corr()
# Out:
#                                 latitude  longitude  minimum_nights  \
# latitude                        1.000000   0.084788        0.024869
# longitude                       0.084788   1.000000       -0.062747
# minimum_nights                  0.024869  -0.062747        1.000000
# number_of_reviews              -0.015389   0.059094       -0.080116
# reviews_per_month              -0.010142   0.145948       -0.121702
# calculated_host_listings_count  0.019517  -0.114713        0.127960
# availability_365               -0.010983   0.082731        0.144303
#
#                                 number_of_reviews  reviews_per_month  \
# latitude                                -0.015389          -0.010142
# longitude                                0.059094           0.145948
# minimum_nights                          -0.080116          -0.121702
# number_of_reviews                        1.000000           0.549868
# reviews_per_month                        0.549868           1.000000
# calculated_host_listings_count          -0.072376          -0.009421
# availability_365                         0.172028           0.185791
#
#                                 calculated_host_listings_count  \
# latitude                                              0.019517
# longitude                                            -0.114713
# minimum_nights                                        0.127960
# number_of_reviews                                    -0.072376
# reviews_per_month                                    -0.009421
# calculated_host_listings_count                        1.000000
# availability_365                                      0.225701
#
#                                 availability_365
# latitude                               -0.010983
# longitude                               0.082731
# minimum_nights                          0.144303
# number_of_reviews                       0.172028
# reviews_per_month                       0.185791
# calculated_host_listings_count          0.225701
# availability_365                        1.000000

# %%
plt.figure(figsize=(15,10))  
sns.heatmap(data_numeric.corr(),annot=True,linewidths=.5, cmap="Blues")
plt.title('Heatmap showing correlations between numerical data')
plt.show()

# %%
data_numeric.corr().unstack().sort_values(ascending = False)
# Out:
# latitude                        latitude                          1.000000
# longitude                       longitude                         1.000000
# calculated_host_listings_count  calculated_host_listings_count    1.000000
# reviews_per_month               reviews_per_month                 1.000000
# minimum_nights                  minimum_nights                    1.000000
# number_of_reviews               number_of_reviews                 1.000000
# availability_365                availability_365                  1.000000
# number_of_reviews               reviews_per_month                 0.549868
# reviews_per_month               number_of_reviews                 0.549868
# availability_365                calculated_host_listings_count    0.225701
# calculated_host_listings_count  availability_365                  0.225701
# availability_365                reviews_per_month                 0.185791
# reviews_per_month               availability_365                  0.185791
# availability_365                number_of_reviews                 0.172028
# number_of_reviews               availability_365                  0.172028
# reviews_per_month               longitude                         0.145948
# longitude                       reviews_per_month                 0.145948
# minimum_nights                  availability_365                  0.144303
# availability_365                minimum_nights                    0.144303
# minimum_nights                  calculated_host_listings_count    0.127960
# calculated_host_listings_count  minimum_nights                    0.127960
# latitude                        longitude                         0.084788
# longitude                       latitude                          0.084788
#                                 availability_365                  0.082731
# availability_365                longitude                         0.082731
# longitude                       number_of_reviews                 0.059094
# number_of_reviews               longitude                         0.059094
# minimum_nights                  latitude                          0.024869
# latitude                        minimum_nights                    0.024869
# calculated_host_listings_count  latitude                          0.019517
# latitude                        calculated_host_listings_count    0.019517
# reviews_per_month               calculated_host_listings_count   -0.009421
# calculated_host_listings_count  reviews_per_month                -0.009421
# reviews_per_month               latitude                         -0.010142
# latitude                        reviews_per_month                -0.010142
#                                 availability_365                 -0.010983
# availability_365                latitude                         -0.010983
# latitude                        number_of_reviews                -0.015389
# number_of_reviews               latitude                         -0.015389
# longitude                       minimum_nights                   -0.062747
# minimum_nights                  longitude                        -0.062747
# calculated_host_listings_count  number_of_reviews                -0.072376
# number_of_reviews               calculated_host_listings_count   -0.072376
#                                 minimum_nights                   -0.080116
# minimum_nights                  number_of_reviews                -0.080116
# calculated_host_listings_count  longitude                        -0.114713
# longitude                       calculated_host_listings_count   -0.114713
# reviews_per_month               minimum_nights                   -0.121702
# minimum_nights                  reviews_per_month                -0.121702
# dtype: float64
